# %% [markdown]
# # Group Project Milestone 1
#
# Task: You will describe your dataset, discuss a few interesting and important questions that you wish to answer using the dataset, present at least three different visualizations of the data, and discuss how these visualizations give insight into the questions you seek to answer. The report will be submitted as a pdf of maximum 4 pages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import statsmodels.graphics.tsaplots as tsa
import seaborn as sns
import csv

# %% [markdown]
# ## Data Description and Exploration
#
# ...

# %%
#accidents2019 = pd.read_csv('acc_19.csv') #,on_bad_lines='skip' ,quoting=csv.QUOTE_NONE
accidents2019 = pd.read_csv('archive/acc_19.csv', sep=',',quotechar='"',quoting=csv.QUOTE_MINIMAL)
pd.set_option('display.max_columns', None)
accidents2019
# Out:
#             CASENUM  STRATUM                              STRATUMNAME  REGION  \
# 0      201901174219       10                       Stratum 10 - Other       3
# 1      201901176655        6          Stratum 6 - LMY PV Minor Injury       3
# 2      201901176667        8         Stratum 8 - NLMY PV Minor Injury       3
# 3      201901176694        9  Stratum 9 - LMY PV No Injuries in Crash       3
# 4      201901176702        6          Stratum 6 - LMY PV Minor Injury       3
# ...             ...      ...                                      ...     ...
# 54404  201902285920        8         Stratum 8 - NLMY PV Minor Injury       4
# 54405  201902285944        7             Stratum 7 - M/H Truck or Bus       2
# 54406  201902285945       10                       Stratum 10 - Other       2
# 54407  201902285953        9  Stratum 9 - LMY PV No Injuries in Crash       2
# 54408  201902285965        6          Stratum 6 - LMY PV Minor Injury       2
#
#                                               REGIONNAME  PSU    PJ  PSU_VAR  \
# 0      South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   75  4144       75
# 1      South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   63  4135       63
# 2      South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   65  4138       65
# 3      South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   12  4142       12
# 4      South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...   12  4142       12
# ...                                                  ...  ...   ...      ...
# 54404  West (MT, ID, WA, OR, CA, NV, NM, AZ, UT, CO, ...   56   206      206
# 54405  Midwest (OH, IN, IL, MI, WI, MN, ND, SD, NE, I...   67  1921       67
# 54406  Midwest (OH, IN, IL, MI, WI, MN, ND, SD, NE, I...   67  1921       67
# 54407  Midwest (OH, IN, IL, MI, WI, MN, ND, SD, NE, I...   67  1921       67
# 54408  Midwest (OH, IN, IL, MI, WI, MN, ND, SD, NE, I...   67  1921       67
#
#        URBANICITY URBANICITYNAME  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERMVIT  \
# 0               2     Rural Area         1         1         0     0        1
# 1               2     Rural Area         2         2         0     0        6
# 2               1     Urban Area         2         2         0     0        2
# 3               1     Urban Area         1         1         0     0        1
# 4               1     Urban Area         2         2         0     0        3
# ...           ...            ...       ...       ...       ...   ...      ...
# 54404           1     Urban Area         2         1         1     0        1
# 54405           1     Urban Area         2         2         0     0        2
# 54406           1     Urban Area         1         1         0     0        1
# 54407           1     Urban Area         2         2         0     0        3
# 54408           1     Urban Area         2         2         0     0        3
#
#        PERNOTMVIT  NUM_INJ                                   NUM_INJNAME  \
# 0               0        0  No Person Injured/Property Damage Only Crash
# 1               0        2                                             2
# 2               0        2                                             2
# 3               0        0  No Person Injured/Property Damage Only Crash
# 4               0        1                                             1
# ...           ...      ...                                           ...
# 54404           0        1                                             1
# 54405           0        0  No Person Injured/Property Damage Only Crash
# 54406           0        0  No Person Injured/Property Damage Only Crash
# 54407           0        0  No Person Injured/Property Damage Only Crash
# 54408           0        1                                             1
#
#        MONTH MONTHNAME  YEAR  YEARNAME  DAY_WEEK DAY_WEEKNAME  HOUR  \
# 0          1   January  2019      2019         3      Tuesday     8
# 1          1   January  2019      2019         3      Tuesday     2
# 2          1   January  2019      2019         3      Tuesday     5
# 3          1   January  2019      2019         3      Tuesday     4
# 4          1   January  2019      2019         3      Tuesday     9
# ...      ...       ...   ...       ...       ...          ...   ...
# 54404     12  December  2019      2019         7     Saturday    22
# 54405      7      July  2019      2019         7     Saturday     5
# 54406      7      July  2019      2019         7     Saturday    16
# 54407      7      July  2019      2019         2       Monday    17
# 54408      7      July  2019      2019         4    Wednesday    16
#
#               HOURNAME  MINUTE MINUTENAME  HARM_EV  \
# 0        8:00am-8:59am       6          6       33
# 1        2:00am-2:59am      12         12       12
# 2        5:00am-5:59am      33         33       12
# 3        4:00am-4:59am       8          8       59
# 4        9:00am-9:59am      41         41       12
# ...                ...     ...        ...      ...
# 54404  10:00pm-10:59pm       0          0       14
# 54405    5:00am-5:59am      12         12       12
# 54406    4:00pm-4:59pm      21         21       25
# 54407    5:00pm-5:59pm      40         40       12
# 54408    4:00pm-4:59pm      33         33       12
#
#                       HARM_EVNAME  ALCOHOL          ALCOHOLNAME  MAX_SEV  \
# 0                            Curb        2  No Alcohol Involved        0
# 1      Motor Vehicle In-Transport        9  Reported as Unknown        1
# 2      Motor Vehicle In-Transport        1     Alcohol Involved        2
# 3            Traffic Sign Support        2  No Alcohol Involved        0
# 4      Motor Vehicle In-Transport        2  No Alcohol Involved        1
# ...                           ...      ...                  ...      ...
# 54404        Parked Motor Vehicle        2  No Alcohol Involved        2
# 54405  Motor Vehicle In-Transport        9  Reported as Unknown        0
# 54406    Concrete Traffic Barrier        9  Reported as Unknown        0
# 54407  Motor Vehicle In-Transport        9  Reported as Unknown        0
# 54408  Motor Vehicle In-Transport        9  Reported as Unknown        2
#
#                       MAX_SEVNAME  MAN_COLL  \
# 0          No Apparent Injury (O)         0
# 1             Possible Injury (C)         6
# 2      Suspected Minor Injury (B)         6
# 3          No Apparent Injury (O)         0
# 4             Possible Injury (C)         6
# ...                           ...       ...
# 54404  Suspected Minor Injury (B)         0
# 54405      No Apparent Injury (O)         1
# 54406      No Apparent Injury (O)         0
# 54407      No Apparent Injury (O)         7
# 54408  Suspected Minor Injury (B)         1
#
#                                             MAN_COLLNAME  RELJCT1  \
# 0      The First Harmful Event was Not a Collision wi...        1
# 1                                                  Angle        8
# 2                                                  Angle        8
# 3      The First Harmful Event was Not a Collision wi...        8
# 4                                                  Angle        0
# ...                                                  ...      ...
# 54404  The First Harmful Event was Not a Collision wi...        8
# 54405                                      Front-to-Rear        8
# 54406  The First Harmful Event was Not a Collision wi...        8
# 54407                         Sideswipe - Same Direction        8
# 54408                                      Front-to-Rear        8
#
#         RELJCT1NAME  RELJCT2                 RELJCT2NAME  TYP_INT  \
# 0               Yes        5  Entrance/Exit Ramp Related        1
# 1      Not Reported        2                Intersection        2
# 2      Not Reported        8     Driveway Access Related        1
# 3      Not Reported        3        Intersection-Related        3
# 4                No        3        Intersection-Related        3
# ...             ...      ...                         ...      ...
# 54404  Not Reported       98                Not Reported        1
# 54405  Not Reported       98                Not Reported        1
# 54406  Not Reported       98                Not Reported       98
# 54407  Not Reported       98                Not Reported        1
# 54408  Not Reported        2                Intersection        2
#
#                  TYP_INTNAME  WRK_ZONE WRK_ZONENAME  REL_ROAD  \
# 0        Not an Intersection         0         None         3
# 1      Four-Way Intersection         0         None         1
# 2        Not an Intersection         0         None         1
# 3             T-Intersection         0         None         4
# 4             T-Intersection         0         None         1
# ...                      ...       ...          ...       ...
# 54404    Not an Intersection         0         None         7
# 54405    Not an Intersection         0         None         1
# 54406           Not Reported         0         None         3
# 54407    Not an Intersection         0         None         1
# 54408  Four-Way Intersection         0         None         1
#
#                REL_ROADNAME  LGT_COND    LGT_CONDNAME  WEATHER1 WEATHER1NAME  \
# 0                 On Median         1        Daylight        10       Cloudy
# 1                On Roadway         3  Dark - Lighted         1        Clear
# 2                On Roadway         3  Dark - Lighted         1        Clear
# 3               On Roadside         3  Dark - Lighted         1        Clear
# 4                On Roadway         1        Daylight         1        Clear
# ...                     ...       ...             ...       ...          ...
# 54404  In Parking Lane/Zone         3  Dark - Lighted        10       Cloudy
# 54405            On Roadway         3  Dark - Lighted         1        Clear
# 54406             On Median         1        Daylight         1        Clear
# 54407            On Roadway         1        Daylight         1        Clear
# 54408            On Roadway         1        Daylight        10       Cloudy
#
#        WEATHER2                          WEATHER2NAME  WEATHER WEATHERNAME  \
# 0             0  No Additional Atmospheric Conditions       10      Cloudy
# 1             0  No Additional Atmospheric Conditions        1       Clear
# 2             0  No Additional Atmospheric Conditions        1       Clear
# 3             0  No Additional Atmospheric Conditions        1       Clear
# 4             0  No Additional Atmospheric Conditions        1       Clear
# ...         ...                                   ...      ...         ...
# 54404         0  No Additional Atmospheric Conditions       10      Cloudy
# 54405         0  No Additional Atmospheric Conditions        1       Clear
# 54406         0  No Additional Atmospheric Conditions        1       Clear
# 54407         0  No Additional Atmospheric Conditions        1       Clear
# 54408         0  No Additional Atmospheric Conditions       10      Cloudy
#
#        SCH_BUS SCH_BUSNAME  INT_HWY INT_HWYNAME  CF1 CF1NAME  CF2 CF2NAME  \
# 0            0          No        0          No    0    None    0    None
# 1            0          No        0          No    0    None    0    None
# 2            0          No        0          No    0    None    0    None
# 3            0          No        0          No    0    None    0    None
# 4            0          No        0          No    0    None    0    None
# ...        ...         ...      ...         ...  ...     ...  ...     ...
# 54404        0          No        0          No    0    None    0    None
# 54405        0          No        1         Yes    0    None    0    None
# 54406        0          No        0          No    0    None    0    None
# 54407        0          No        0          No    0    None    0    None
# 54408        0          No        1         Yes    0    None    0    None
#
#        CF3 CF3NAME  PSUSTRAT      WEIGHT  WKDY_IM WKDY_IMNAME  HOUR_IM  \
# 0        0    None        19  203.665120        3     Tuesday        8
# 1        0    None        16   59.073459        3     Tuesday        2
# 2        0    None        13  133.664224        3     Tuesday        5
# 3        0    None        12  153.783414        3     Tuesday        4
# 4        0    None        12   60.383244        3     Tuesday        9
# ...    ...     ...       ...         ...      ...         ...      ...
# 54404    0    None        20  151.492666        7    Saturday       22
# 54405    0    None         8  131.554091        7    Saturday        5
# 54406    0    None         8  207.016196        7    Saturday       16
# 54407    0    None         8  151.020531        2      Monday       17
# 54408    0    None         8   58.964190        4   Wednesday       16
#
#            HOUR_IMNAME  MINUTE_IM  MINUTE_IMNAME  EVENT1_IM  \
# 0        8:00am-8:59am          6              6         33
# 1        2:00am-2:59am         12             12         12
# 2        5:00am-5:59am         33             33         12
# 3        4:00am-4:59am          8              8         59
# 4        9:00am-9:59am         41             41         12
# ...                ...        ...            ...        ...
# 54404  10:00pm-10:59pm          0              0         14
# 54405    5:00am-5:59am         12             12         12
# 54406    4:00pm-4:59pm         21             21         25
# 54407    5:00pm-5:59pm         40             40         12
# 54408    4:00pm-4:59pm         33             33         12
#
#                     EVENT1_IMNAME  MANCOL_IM  \
# 0                            Curb          0
# 1      Motor Vehicle In-Transport          6
# 2      Motor Vehicle In-Transport          6
# 3            Traffic Sign Support          0
# 4      Motor Vehicle In-Transport          6
# ...                           ...        ...
# 54404        Parked Motor Vehicle          0
# 54405  Motor Vehicle In-Transport          1
# 54406    Concrete Traffic Barrier          0
# 54407  Motor Vehicle In-Transport          7
# 54408  Motor Vehicle In-Transport          1
#
#                                            MANCOL_IMNAME  RELJCT2_IM  \
# 0      The First Harmful Event was Not a Collision wi...           5
# 1                                                  Angle           2
# 2                                                  Angle           8
# 3      The First Harmful Event was Not a Collision wi...           3
# 4                                                  Angle           3
# ...                                                  ...         ...
# 54404  The First Harmful Event was Not a Collision wi...           1
# 54405                                      Front-to-Rear           1
# 54406  The First Harmful Event was Not a Collision wi...           3
# 54407                         Sideswipe - Same Direction           1
# 54408                                      Front-to-Rear           2
#
#                    RELJCT2_IMNAME  LGTCON_IM   LGTCON_IMNAME  WEATHR_IM  \
# 0      Entrance/Exit Ramp Related          1        Daylight         10
# 1                    Intersection          3  Dark - Lighted          1
# 2         Driveway Access Related          3  Dark - Lighted          1
# 3            Intersection-Related          3  Dark - Lighted          1
# 4            Intersection-Related          1        Daylight          1
# ...                           ...        ...             ...        ...
# 54404                Non-Junction          3  Dark - Lighted         10
# 54405                Non-Junction          3  Dark - Lighted          1
# 54406        Intersection-Related          1        Daylight          1
# 54407                Non-Junction          1        Daylight          1
# 54408                Intersection          1        Daylight         10
#
#       WEATHR_IMNAME  MAXSEV_IM               MAXSEV_IMNAME  NO_INJ_IM  \
# 0            Cloudy          0      No Apparent Injury (O)          0
# 1             Clear          1         Possible Injury (C)          2
# 2             Clear          2  Suspected Minor Injury (B)          2
# 3             Clear          0      No Apparent Injury (O)          0
# 4             Clear          1         Possible Injury (C)          1
# ...             ...        ...                         ...        ...
# 54404        Cloudy          2  Suspected Minor Injury (B)          1
# 54405         Clear          0      No Apparent Injury (O)          0
# 54406         Clear          0      No Apparent Injury (O)          0
# 54407         Clear          0      No Apparent Injury (O)          0
# 54408        Cloudy          2  Suspected Minor Injury (B)          1
#
#                                       NO_INJ_IMNAME  ALCHL_IM  \
# 0      No Person Injured/Property Damage Only Crash         2
# 1                                                 2         2
# 2                                                 2         1
# 3      No Person Injured/Property Damage Only Crash         2
# 4                                                 1         2
# ...                                             ...       ...
# 54404                                             1         2
# 54405  No Person Injured/Property Damage Only Crash         2
# 54406  No Person Injured/Property Damage Only Crash         2
# 54407  No Person Injured/Property Damage Only Crash         2
# 54408                                             1         2
#
#               ALCHL_IMNAME
# 0      No Alcohol Involved
# 1      No Alcohol Involved
# 2         Alcohol Involved
# 3      No Alcohol Involved
# 4      No Alcohol Involved
# ...                    ...
# 54404  No Alcohol Involved
# 54405  No Alcohol Involved
# 54406  No Alcohol Involved
# 54407  No Alcohol Involved
# 54408  No Alcohol Involved
#
# [54409 rows x 88 columns]

# %% [markdown]
# ## Question 1, 2, 3...
#
# *insert work here*

# %% [markdown]
# ### Demographic Exploration

# %%
#load and view demo data from person csv , sep=',',quotechar='"',quoting=csv.QUOTE_MINIMAL
victims2019= pd.read_csv('archive/pers_19.csv')
pd.set_option('display.max_columns', None)
victims2019
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 #load and view demo data from person csv , sep=',',quotechar='"',quoting=csv.QUOTE_MINIMAL
# ----> 2 victims2019= pd.read_csv('archive/pers_19.csv')
#       3 pd.set_option('display.max_columns', None)
#       4 victims2019
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1255, in TextFileReader.read(self, nrows)
#    1253 nrows = validate_integer("nrows", nrows)
#    1254 try:
# -> 1255     index, columns, col_dict = self._engine.read(nrows)
#    1256 except Exception:
#    1257     self.close()
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/opt/anaconda3/envs/info2950/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:1952, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x96 in position 240860: invalid start byte

# %%
#getting a count of accidents by intersection type as its own dataframe
g=accidents2019['TYP_INTNAME'].value_counts()
frame = {'intersections': g}
intersections = pd.DataFrame(frame)
intersections

# %%
accidents2019['TYP_INTNAME'].value_counts().plot(kind='bar')

# %%
accidents2019['TYP_INTNAME'].value_counts().plot(kind='pie')

# %% [markdown]
# ...

# %% [markdown]
# ## Question 4
#
# ### What are the leading factors present in accidents?
# Potential factors to Explore: Weather related/non driver fault, seatbealt usage, driver neglect, alcohol consumption, lighting conditions

# %%
lighting = accidents2019.groupby('LGTCON_IMNAME')['CASENUM'].count().sort_values(ascending=False).reset_index()
lighting['CASENUM'] = lighting['CASENUM']/len(accidents2019)

for i in range(len(lighting['CASENUM'])):
    if(lighting['CASENUM'][i] < 0.01):
        lighting['LGTCON_IMNAME'][i] = "Other"

lighting = lighting.groupby('LGTCON_IMNAME')['CASENUM'].sum().sort_values(ascending=False).reset_index()
        
display(lighting)

plt.bar(lighting['LGTCON_IMNAME'], lighting['CASENUM'])
plt.xticks(rotation = 90)
plt.title("Traffic Accidents - Lighting Conditions")
plt.show()
# Out:
# /var/folders/jc/cnb4b2bn5n7735g1khddrls80000gn/T/ipykernel_26252/1005319466.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lighting['LGTCON_IMNAME'][i] = "Other"
#         LGTCON_IMNAME   CASENUM
# 0            Daylight  0.688857
# 1      Dark - Lighted  0.166296
# 2  Dark - Not Lighted  0.098844
# 3                Dusk  0.023250
# 4                Dawn  0.016431
# 5               Other  0.006322

# %%
weather = accidents2019.groupby('WEATHR_IMNAME')['CASENUM'].count().sort_values(ascending=False).reset_index()
weather['CASENUM'] = weather['CASENUM']/len(accidents2019)

for i in range(len(weather['CASENUM'])):
    if(weather['CASENUM'][i] < 0.01):
        weather['WEATHR_IMNAME'][i] = "Other"

weather = weather.groupby('WEATHR_IMNAME')['CASENUM'].sum().sort_values(ascending=False).reset_index()
        
display(weather)

plt.bar(weather['WEATHR_IMNAME'], weather['CASENUM'])
plt.xticks(rotation = 90)
plt.title("Traffic Accidents - Weather Conditions")
plt.show()
# Out:
# /var/folders/jc/cnb4b2bn5n7735g1khddrls80000gn/T/ipykernel_26252/2022567161.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weather['WEATHR_IMNAME'][i] = "Other"
#   WEATHR_IMNAME   CASENUM
# 0         Clear  0.722197
# 1        Cloudy  0.149203
# 2          Rain  0.101564
# 3          Snow  0.019206
# 4         Other  0.007830

# %%
alcohol = accidents2019.groupby('ALCOHOLNAME')['CASENUM'].count().sort_values(ascending=False).reset_index()
alcohol['CASENUM'] = alcohol['CASENUM']/len(accidents2019)

for i in range(len(alcohol['CASENUM'])):
    if(alcohol['CASENUM'][i] < 0.01):
        alcohol['ALCOHOLNAME'][i] = "Other"

alcohol = alcohol.groupby('ALCOHOLNAME')['CASENUM'].sum().sort_values(ascending=False).reset_index()

display(alcohol)

plt.bar(alcohol['ALCOHOLNAME'], alcohol['CASENUM'])
plt.xticks(rotation = 30)
plt.title("Traffic Accidents - Alcohol Involvement")
plt.show()
# Out:
# /var/folders/jc/cnb4b2bn5n7735g1khddrls80000gn/T/ipykernel_26252/4097120794.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alcohol['ALCOHOLNAME'][i] = "Other"
#            ALCOHOLNAME   CASENUM
# 0  No Alcohol Involved  0.636200
# 1  Reported as Unknown  0.318238
# 2     Alcohol Involved  0.045029
# 3                Other  0.000533

# %%
intersection = accidents2019.groupby('TYP_INTNAME')['CASENUM'].count().sort_values(ascending=False).reset_index()
intersection['CASENUM'] = intersection['CASENUM']/len(accidents2019)

for i in range(len(intersection['CASENUM'])):
    if(intersection['CASENUM'][i] < 0.01):
        intersection['TYP_INTNAME'][i] = "Other"

intersection = intersection.groupby('TYP_INTNAME')['CASENUM'].sum().sort_values(ascending=False).reset_index()

display(intersection)

plt.bar(intersection['TYP_INTNAME'], intersection['CASENUM'])
plt.xticks(rotation = 90)
plt.title("Traffic Accidents - Intersection Type")
plt.show()
# Out:
# /var/folders/jc/cnb4b2bn5n7735g1khddrls80000gn/T/ipykernel_26252/3795887840.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   intersection['TYP_INTNAME'][i] = "Other"
#              TYP_INTNAME   CASENUM
# 0    Not an Intersection  0.531456
# 1  Four-Way Intersection  0.233895
# 2           Not Reported  0.128508
# 3         T-Intersection  0.097723
# 4                  Other  0.008418

# %%
urban_rural = accidents2019.groupby('URBANICITYNAME')['CASENUM'].count().sort_values(ascending=False).reset_index()
urban_rural['CASENUM'] = urban_rural['CASENUM']/len(accidents2019)

for i in range(len(weather['CASENUM'])):
    if(weather['CASENUM'][i] < 0.01):
        weather['WEATHR_IMNAME'][i] = "Other"

weather = weather.groupby('WEATHR_IMNAME')['CASENUM'].sum().sort_values(ascending=False).reset_index()

display(urban_rural)

plt.bar(urban_rural['URBANICITYNAME'], urban_rural['CASENUM'])
plt.xticks(rotation = 30)
plt.title("Traffic Accidents - Urban vs. Rural")
plt.show()
# Out:
#   URBANICITYNAME   CASENUM
# 0     Urban Area  0.776636
# 1     Rural Area  0.223364

# %%
related_junction = accidents2019.groupby('RELJCT2NAME')['CASENUM'].count().sort_values(ascending=False).reset_index()
related_junction['CASENUM'] = related_junction['CASENUM']/len(accidents2019)

for i in range(len(related_junction['CASENUM'])):
    if(related_junction['CASENUM'][i] < 0.01):
        related_junction['RELJCT2NAME'][i] = "Other"

related_junction = related_junction.groupby('RELJCT2NAME')['CASENUM'].sum().sort_values(ascending=False).reset_index()

display(related_junction)

plt.bar(related_junction['RELJCT2NAME'], related_junction['CASENUM']/len(accidents2019))
plt.xticks(rotation = 90)
plt.title("Traffic Accidents - Related Junction")
plt.show()
# Out:
# /var/folders/jc/cnb4b2bn5n7735g1khddrls80000gn/T/ipykernel_26252/2437609170.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   related_junction['RELJCT2NAME'][i] = "Other"
#                   RELJCT2NAME   CASENUM
# 0                Not Reported  0.278906
# 1        Intersection-Related  0.230311
# 2                Intersection  0.219559
# 3                Non-Junction  0.170854
# 4     Driveway Access Related  0.062894
# 5                       Other  0.027367
# 6  Entrance/Exit Ramp Related  0.010109

# %%
time = accidents2019.groupby('HOUR_IM')['CASENUM'].count().reset_index()
time['CASENUM'] = time['CASENUM']/len(accidents2019)

display(time)

plt.plot(time['HOUR_IM'], time['CASENUM'])
plt.xticks(rotation = 90)
plt.title("Traffic Accidents - Time")
plt.show()
# Out:
#     HOUR_IM   CASENUM
# 0         0  0.016541
# 1         1  0.012682
# 2         2  0.012388
# 3         3  0.009502
# 4         4  0.009520
# 5         5  0.017130
# 6         6  0.030271
# 7         7  0.052381
# 8         8  0.051168
# 9         9  0.041335
# 10       10  0.040949
# 11       11  0.050819
# 12       12  0.057950
# 13       13  0.057123
# 14       14  0.065375
# 15       15  0.077763
# 16       16  0.078902
# 17       17  0.086272
# 18       18  0.065302
# 19       19  0.046555
# 20       20  0.038927
# 21       21  0.033983
# 22       22  0.026650
# 23       23  0.020511
